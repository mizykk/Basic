# %% [markdown]
# <a href="https://colab.research.google.com/github/mizykk/Basic/blob/master/matplotlib_pyplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [Matplotlib](https://matplotlib.org/index.html)

# %% [markdown]
# ### Library

# %%
import matplotlib.pyplot as plt
# plot이 나타나게한다.
# %matplotlib inline

# %% [markdown]
# ### [**plt.plot([x축 데이터], [y축 데이터])**](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html?highlight=pyplot%20plot#matplotlib.pyplot.plot) : 선그래프

# %%
plt.plot([1, 2, 3, 4], [10, 20, 30, 40])   # plt.plot([x축 데이터], [y축 데이터])
plt.title('Title')   # plot.title('제목')
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# &nbsp; *label* & **plt.legend()** : 범례
# &nbsp; *color* : 색상
# &nbsp; *linestyle(= ls)* : 선 모양

# %%
plt.plot([10, 20, 30, 40], label = "asc", color = 'red', linestyle = "--")   # 증가
plt.plot([40, 30, 20, 10], label = "desc", color = 'green', linestyle = ":")   # 감소
plt.legend(loc = 8)   # label 값이 범례로 나타난다.

# %% [markdown]
# legend에서 loc = n의 속성으로 범례의 위치를 조정할 수 있다. n은 0~10을 넣을 수 있다.
#
# |2|9|1|
# |---|---|---|
# |6|10|5, 7|
# |3|8|4|

# %% [markdown]
# &nbsp; *marker* : 점표시
# - "--" 점선
# - "s" 네모
# - "^" 삼각형

# %%
plt.title("marker")   # 제목 설정
plt.plot([10, 20, 30, 40], label = "circle", marker = ".")
plt.plot([40, 30, 20, 10], "g^", label = "triangle")   # color와 한번에 지정 가능하다.

# %%
import numpy as np
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')   # "--" 점선, "s" 네모, "^" 삼각형
# Out:
# [<matplotlib.lines.Line2D at 0x7fcb65b82e48>,
#  <matplotlib.lines.Line2D at 0x7fcb65b82fd0>,
#  <matplotlib.lines.Line2D at 0x7fcb65b91128>]

# %% [markdown]
# ### [**plt.hist(x)**](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hist.html?highlight=hist#matplotlib.pyplot.hist) : 히스토그램
# bins : 구간의 크기

# %%
plt.hist([1, 2, 2, 3, 4, 5, 5, 6, 7], bins = 5)   # 히스토그램
# Out:
# (array([3., 1., 1., 2., 2.]),
#  array([1. , 2.2, 3.4, 4.6, 5.8, 7. ]),
#  <a list of 5 Patch objects>)

# %% [markdown]
# ### [**plt.bar(x, height)**](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.bar.html?highlight=bar#matplotlib.pyplot.bar)   : 막대그래프

# %%
plt.bar(['Apple', 'Banana', 'Cherry'], [1500, 5500, 300], color = 'lightskyblue')
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### [**plt.barh()**](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.barh.html?highlight=pyplot%20barh#matplotlib.pyplot.barh) : 수평 막대그래프

# %%
plt.barh([1, 2, 3, 4], [2, 5, 1, 4], color = 'salmon')
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### [**plt.scatter(x, y)**](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html?highlight=scatter#matplotlib.pyplot.scatter) : 산점도, 버블차트
# &nbsp; *s* : 크기(size)
# &nbsp; *c* : 표현하고 싶은 색상(color)의 수, 색 지정
# &nbsp; *marker* : 찍히는 점의 모양
# &nbsp; *cmap* : colormaps을 이용한 색 지정
# &nbsp; *alpha* : 투명도 0(투명)~1(불투명)
# &nbsp; ***plt.colorbar()*** : colorbar 추가

# %%
# scatter를 표현하기 위한 임의의 x, y, size 생성
import random

x = []
y = []
size = []
for i in range(100):
  x.append(random.randint(50, 100))
  y.append(random.randint(50, 100))
  size.append(random.randint(10, 100))

# %%
plt.scatter(x, y, s = size, c = size, cmap = 'jet', alpha = 2)
plt.colorbar()   # colorbar 추가

# %% [markdown]
# ### [**plt.boxplot()**](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.boxplot.html?highlight=boxplot#matplotlib.pyplot.boxplot) : 상자그림
# &nbsp; showfliers = False : 아웃라이어 값 생략

# %%
plt.boxplot([5, 6, 3, 1, 5, 2])   # 상자그림
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fcb63165278>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fcb63165c88>,
#   <matplotlib.lines.Line2D at 0x7fcb630f4048>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fcb630f4748>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fcb630f43c8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fcb63165588>,
#   <matplotlib.lines.Line2D at 0x7fcb63165908>]}

# %%
plt.boxplot([5, 6, 3, 1, 5, 2], vert = False)   # 상자그림, 수평
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fcb630c3dd8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fcb630d2828>,
#   <matplotlib.lines.Line2D at 0x7fcb630d2ba8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fcb630db2e8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fcb630d2f28>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fcb630d2128>,
#   <matplotlib.lines.Line2D at 0x7fcb630d24a8>]}

# %% [markdown]
# ### [**plt.pie()**](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.pie.html?highlight=pie#matplotlib.pyplot.pie) : 파이그래프
# &nbsp; *labels* : 레이블 추가
# &nbsp; *autopct* : 비율 표시  '%.1f%%' : 소수점 아래 둘째 자리에서 반올림
# &nbsp; *startangle* : 시작 각도 정하기

# %%
plt.pie([10, 20], labels = ['A', 'B'], autopct = "%.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7fcb630a7978>,
#   <matplotlib.patches.Wedge at 0x7fcb63035160>],
#  [Text(0.5499999702695115, 0.9526279613277875, 'A'),
#   Text(-0.5499998810780428, -0.9526280128224968, 'B')],
#  [Text(0.2999999837833699, 0.5196152516333385, '33.3%'),
#   Text(-0.29999993513347784, -0.5196152797213618, '66.7%')])

# %%
plt.pie([10, 20], labels = ['A', 'B'], autopct = "%.1f%%", startangle = 90)   # startangle을 정했을 때
# Out:
# ([<matplotlib.patches.Wedge at 0x7fcb62ff1978>,
#   <matplotlib.patches.Wedge at 0x7fcb62fff160>],
#  [Text(-0.9526279613277876, 0.5499999702695114, 'A'),
#   Text(0.9526280128224967, -0.5499998810780429, 'B')],
#  [Text(-0.5196152516333387, 0.29999998378336984, '33.3%'),
#   Text(0.5196152797213618, -0.2999999351334779, '66.7%')])

# %% [markdown]
# ## 기타

# %% [markdown]
# **plt.title('제목')** : 그래프에 제목 추가
# **plt.xlabel('x축 이름')** : x축 이름 지정
# **plt.ylabel('y축 이름')** : y축 이름 지정
# **plt.label()** : 범례
# **plt.style.use('ggplot')** : 배경 격자무늬 스타일 지정
# [**plt.colorbar()**](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.colorbar.html?highlight=colorbar#matplotlib.pyplot.colorbar) : colorbar 추가
# **plt.xticks(rotation=각도)** : x축 각도조정
# **Colors**
# ![matplotlib Colors](https://matplotlib.org/3.1.0/_images/sphx_glr_named_colors_003.png)

# %%
plt.style.use('ggplot')   # 배경 격자 무늬 스타일 지정
plt.plot([1, 2, 3, 4])
plt.title('Title')   # 제목
plt.xlabel('X')   # x축 제목
plt.ylabel('Y')   # y축 제목
plt.xticks(rotation=30)   # x축 각도조정
# Out:
# (array([-0.5,  0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5]),
#  <a list of 9 Text major ticklabel objects>)

# %% [markdown]
# plt.style.use()
# * 'default'
# * 'dark_background'
# * 'classic'
# * 'ggplot'
# * 'seaborn'

# %% [markdown]
# [**plt.figure()**](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.figure.html?highlight=pyplot%20figure#matplotlib.pyplot.figure)
# 그래프 크기 조절하기

# %%
plt.figure(figsize = (10, 2))

# %% [markdown]
# [**plt.rcParams['figure.figsize'] = [width, height]**](https://matplotlib.org/api/matplotlib_configuration_api.html?highlight=rcparams#matplotlib.rcParams)
# 그래프 크기 조절하기

# %%
plt.rcParams['figure.figsize'] = [10, 5] # [width, height] (inches)

# %% [markdown]
# [**plt.subplot(nrows, ncols, index)**](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html#matplotlib.pyplot.subplot)
# 그래프 여러개 그리기

# %%
plt.subplot(121)   # = plt.subplot(2, 2, 1)
plt.plot([1, 2, 3], [1, 2, 3])

plt.subplot(122) 
plt.plot([4, 6, 8], [1, 2, 3])

# %% [markdown]
# #### 한글 나타나게

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="/System/Library/Fonts/AppleSDGothicNeo.ttc").get_name()   # 폰트 위치
rc('font', family=font_name)

# %% [markdown]
# #### 그래프 바깥에 범례 나타나게하기

# %%
plt.plot([10, 20, 30, 40], label = "asc", color = 'red', linestyle = "--")   # 증가
plt.plot([40, 30, 20, 10], label = "desc", color = 'green', linestyle = ":")   # 감소

# Put the legend out of the figure
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
